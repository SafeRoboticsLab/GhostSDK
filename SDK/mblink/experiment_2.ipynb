# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
force_file = "2024-02-01-23-05-40-zp_500n.csv"
vicon_file = "2024-02-01-23-05-40-vicon-spirit-spirit.csv"

# %%
force_data = pd.read_csv(force_file)
vicon_data = pd.read_csv(vicon_file)

# %%
force_data.columns
# Out:
# Index(['time', '.header.seq', '.header.stamp.secs', '.header.stamp.nsecs',
#        '.header.frame_id', '.data'],
#       dtype='object')

# %%
vicon_data.columns
# Out:
# Index(['time', '.header.seq', '.header.stamp.secs', '.header.stamp.nsecs',
#        '.header.frame_id', '.child_frame_id', '.transform.translation.x',
#        '.transform.translation.y', '.transform.translation.z',
#        '.transform.rotation.x', '.transform.rotation.y',
#        '.transform.rotation.z', '.transform.rotation.w'],
#       dtype='object')

# %%
force_data[".header.stamp.secs"].plot()
# Out:
# <AxesSubplot:>

# %%
vicon_data[".header.stamp.secs"].plot()
# Out:
# <AxesSubplot:>

# %%
vicon_data[]

# %%
force_data["time"].iloc[-1]
# Out:
# '2024/02/01/22:54:06.594158'

# %%
vicon_data["time"].iloc[-1]
# Out:
# '2024/02/01/22:54:06.635713'
